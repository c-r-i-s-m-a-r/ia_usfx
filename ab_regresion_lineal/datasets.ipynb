# %%
import joblib
import numpy

# %%
# Datos del ejemplo de la clase
metros_cuadrados = [
    50,
    110,
    180,
    200,
    205,
    240,
    300,
    380,
    400,
    500
]
precio = [
    20000,
    30000,
    60000,
    12000,
    13000,
    12500,
    300000,
    310000,
    500000,
    700000
]


# Datos generados para mi problema
numpy.random.seed(17)
temperatura = numpy.linspace(12, 38, 100)

a_real = 0.7
b_real = 4.2
ruido = numpy.random.normal(0, 6.4, size=len(temperatura))

ventas_helado = a_real + b_real * temperatura + ruido
joblib.dump(temperatura, 'variables/temperatura.joblib')
joblib.dump(ventas_helado, 'variables/ventas_helado.joblib')
pass
